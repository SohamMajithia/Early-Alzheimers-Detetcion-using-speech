# %%
# Ensure all necessary packages are installed
# !pip install gTTS pydub tqdm streamlit joblib librosa numpy pandas scikit-learn pyngrok
# !apt install -y ffmpeg # Required by pydub for mp3 to wav conversion
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Collecting streamlit
#   Downloading streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.2)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Collecting pyngrok
#   Downloading pyngrok-7.4.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from gTTS) (2.32.4)
# Collecting click<8.2,>=7.1 (from gTTS)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow<22,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.16.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.10.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->gTTS) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Downloading streamlit-1.51.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 81.6 MB/s eta 0:00:00
# Downloading pyngrok-7.4.1-py3-none-any.whl (25 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.1 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 136.6 MB/s eta 0:00:00
# Installing collected packages: pyngrok, click, pydeck, gTTS, streamlit
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# Successfully installed click-8.1.8 gTTS-2.5.4 pydeck-0.9.1 pyngrok-7.4.1 streamlit-1.51.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# --- 1. IMPORT LIBRARIES ---
from gtts import gTTS
from pydub import AudioSegment
import os, random, csv, time
import pandas as pd
import numpy as np
import joblib
import librosa
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold, GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from google.colab import drive
from pyngrok import ngrok

# --- 2. CONNECT TO GOOGLE DRIVE ---
drive.mount('/content/drive')

# Base directory for the entire dataset
BASE_DIR = '/content/drive/MyDrive/synthetic_AD_dataset_final'
os.makedirs(BASE_DIR, exist_ok=True)

# --- 3. NGROK AUTHENTICATION ---
# IMPORTANT: Replace YOUR_AUTH_TOKEN_HERE with your actual ngrok token
# If you run this without replacing the token, ngrok will not work.
# Authentication is handled in the cell that launches the Streamlit app for better reliability.

# Define file paths
MODEL_PATH = os.path.join(BASE_DIR, "best_rf_model.pkl")
SCALER_PATH = os.path.join(BASE_DIR, "scaler.pkl")
LABELS_CSV_PATH = os.path.join(BASE_DIR, "labels.csv")

print(f"Dataset root set to: {BASE_DIR}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Mounted at /content/drive
# Dataset root set to: /content/drive/MyDrive/synthetic_AD_dataset_final

# %%
# --- STEP 3: FOLDER STRUCTURE (Remains the same) ---
folders = ['AD/audio', 'AD/transcripts', 'CN/audio', 'CN/transcripts']
for f in folders:
    os.makedirs(os.path.join(BASE_DIR, f), exist_ok=True)

# --- STEP 4 & 5: SENTENCE POOLS & MAKE_SENTENCE FUNCTION (Remains the same) ---
ad_templates = [
    "Uh, I, um, I was going to tell you about my, uh, {thing}, but I forgot what it was.",
    "I was, um, talking about, uh, {topic}, I think, but I lost my train of thought.",
    "Sometimes I, uh, forget what I was saying, like, uh, right now.",
    "You know, I was, uh, trying to find that, uh, {object}, but I can’t remember where I put it.",
    "It’s, uh, hard to remember names lately, you know, uh, people I see often.",
    "I went to the, uh, {place}, I think, maybe yesterday, or, um, the day before?",
    "My, uh, daughter or maybe my niece, she, uh, she came over last week, I think.",
    "I, I, I think I left the, um, the {thing} on the table, I believe.",
    "We, we were going to the, the {place} for lunch, but I forget when."
]
cn_templates = [
    "I went to the {place} yesterday to buy some {thing}.",
    "My {relative} and I talked about {topic} while having dinner.",
    "I enjoy going to the {place} every weekend.",
    "I love watching movies with my {relative} on Fridays.",
    "The weather this morning was perfect for going to the {place}.",
    "I need to buy a new {object} because the old one stopped working.",
    "I finished reading that {thing} I borrowed from my {relative}.",
    "We had a long discussion about {topic} at the meeting today."
]
fillers = {
    "place": ["park", "market", "store", "beach", "office", "library", "gym"],
    "thing": ["book", "phone", "bag", "laptop", "keys", "wallet", "tablet"],
    "relative": ["mother", "father", "friend", "brother", "sister", "aunt", "uncle"],
    "object": ["car", "computer", "fan", "bottle", "table", "chair"],
    "topic": ["weather", "sports", "technology", "food", "music", "history"]
}
def make_sentence(template):
    out = template
    for key in fillers:
        out = out.replace(f"{{{key}}}", random.choice(fillers[key]))
    return out


# --- STEP 6: GENERATE DATA WITH MAX AMBIGUITY AND APPEND ---
num_samples_to_add = 500  # per class (Total new count = 1000)
accents = ['en', 'en-uk']
new_labels = []

# --- Determine starting index for appending (KEY CHANGE) ---
def get_next_index(label):
    folder_path = os.path.join(BASE_DIR, label, 'audio')
    # List all files and find the highest index used
    existing_files = [f for f in os.listdir(folder_path) if f.startswith(label.lower() + '_')]
    if not existing_files:
        return 1

    # Extract index numbers (e.g., from 'ad_0001.wav')
    max_index = 0
    for f in existing_files:
        try:
            # Assumes 4-digit formatting (0001)
            max_index = max(max_index, int(f[-8:-4]))
        except:
            continue
    return max_index + 1

print("Generating 1000 new samples with MAXIMUM ambiguity and appending to dataset...")

for label, templates, subdir in [('AD', ad_templates, 'AD'), ('CN', cn_templates, 'CN')]:

    start_index = get_next_index(label)

    # Define speed factor based on class: (MAX AMBIGUITY LOGIC)
    if label == 'AD':
        base_min_speed, base_max_speed = 0.90, 1.05
    else: # CN
        base_min_speed, base_max_speed = 0.95, 1.10

    for i in tqdm(range(num_samples_to_add), desc=f"Appending {label}"):

        current_index = start_index + i
        text = make_sentence(random.choice(templates))
        # Use current_index for the filename
        filename = f"{label.lower()}_{current_index:04}.wav"

        try:
            accent = random.choice(accents)
            tts = gTTS(text=text, lang=accent, slow=False)
            temp_mp3_path = f"/content/{current_index}_temp.mp3"
            tts.save(temp_mp3_path)

            sound = AudioSegment.from_file(temp_mp3_path, format="mp3")

            # --- 1. SPEECH RATE AMBIGUITY ---
            speed_factor = random.uniform(base_min_speed, base_max_speed)

            # CRITICAL: Introduce cross-class ambiguity 15% of the time
            if random.random() < 0.15:
                if label == 'AD':
                    speed_factor = random.uniform(1.05, 1.15)
                else:
                    speed_factor = random.uniform(0.85, 0.95)

            augmented_sound = sound._spawn(sound.raw_data, overrides={
                "frame_rate": int(sound.frame_rate * speed_factor)
            }).set_frame_rate(sound.frame_rate)

            # --- 2. EXTREME NOISE AUGMENTATION ---
            noise_duration = len(augmented_sound)
            noise = AudioSegment.from_mono_audiosegments(
                AudioSegment.silent(duration=noise_duration).set_frame_rate(augmented_sound.frame_rate).set_sample_width(augmented_sound.sample_width)
            )
            # EXTREME NOISE: Volume range is much higher
            noise = noise + random.uniform(-40, -25)

            final_sound = augmented_sound.overlay(noise)

            # 3. Export augmented sound to WAV
            wav_path = os.path.join(BASE_DIR, f"{subdir}/audio/{filename}")
            final_sound.export(wav_path, format="wav")

            new_labels.append([filename, label])

            os.remove(temp_mp3_path)
            time.sleep(0.3)
        except Exception as e:
            if i < 5:
                print(f"Error at index {i} for {filename}: {e}")
            continue

# --- APPEND LABELS TO CSV (KEY CHANGE) ---
new_labels_df = pd.DataFrame(new_labels, columns=['filename', 'label'])

try:
    # Load existing labels and append the new ones
    existing_labels_df = pd.read_csv(LABELS_CSV_PATH)
    combined_labels_df = pd.concat([existing_labels_df, new_labels_df], ignore_index=True)
except FileNotFoundError:
    # If the file doesn't exist (first run), just use the new labels
    combined_labels_df = new_labels_df

# Save the combined DataFrame (overwrites old CSV with new appended data)
combined_labels_df.to_csv(LABELS_CSV_PATH, index=False)
print(f"\n ✅ Dataset generation complete. {len(new_labels)} new samples appended. Total samples: {len(combined_labels_df)}.")
# Out:
# Generating 1000 new samples with MAXIMUM ambiguity and appending to dataset...
# Appending AD:   0%|          | 0/500 [00:00<?, ?it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   0%|          | 1/500 [00:01<08:25,  1.01s/it]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   1%|          | 3/500 [00:02<07:35,  1.09it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   1%|          | 4/500 [00:03<07:11,  1.15it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   1%|          | 5/500 [00:04<07:13,  1.14it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   1%|▏         | 7/500 [00:06<07:03,  1.17it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   2%|▏         | 9/500 [00:07<06:45,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   3%|▎         | 14/500 [00:11<06:31,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   4%|▎         | 18/500 [00:14<06:24,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   4%|▍         | 19/500 [00:15<06:23,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   4%|▍         | 21/500 [00:17<06:27,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   5%|▍         | 24/500 [00:19<06:09,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   5%|▌         | 26/500 [00:21<06:14,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   5%|▌         | 27/500 [00:22<06:11,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   6%|▌         | 28/500 [00:22<06:03,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   6%|▌         | 29/500 [00:23<06:07,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   6%|▌         | 31/500 [00:25<06:06,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   7%|▋         | 34/500 [00:27<05:50,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   7%|▋         | 37/500 [00:29<06:23,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   8%|▊         | 38/500 [00:30<06:07,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   8%|▊         | 39/500 [00:31<06:04,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   8%|▊         | 40/500 [00:32<06:06,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   8%|▊         | 42/500 [00:33<06:14,  1.22it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   9%|▊         | 43/500 [00:34<06:06,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   9%|▉         | 45/500 [00:36<06:05,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   9%|▉         | 46/500 [00:37<06:01,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:   9%|▉         | 47/500 [00:37<05:59,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  10%|▉         | 48/500 [00:38<06:02,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  10%|▉         | 49/500 [00:39<05:57,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  10%|█         | 50/500 [00:40<05:53,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  10%|█         | 51/500 [00:41<05:53,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  11%|█         | 55/500 [00:44<06:08,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  13%|█▎        | 63/500 [00:50<05:33,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  13%|█▎        | 64/500 [00:51<05:42,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  13%|█▎        | 65/500 [00:52<05:39,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  13%|█▎        | 66/500 [00:52<05:24,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  14%|█▍        | 69/500 [00:55<05:56,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  14%|█▍        | 71/500 [00:57<05:54,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  14%|█▍        | 72/500 [00:57<05:37,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  15%|█▍        | 74/500 [00:59<05:14,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  15%|█▌        | 75/500 [00:59<05:07,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  15%|█▌        | 77/500 [01:01<05:11,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  16%|█▌        | 80/500 [01:03<05:27,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  16%|█▋        | 82/500 [01:05<05:33,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  17%|█▋        | 87/500 [01:09<05:26,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  18%|█▊        | 89/500 [01:10<05:11,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  18%|█▊        | 91/500 [01:12<05:18,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  18%|█▊        | 92/500 [01:13<05:16,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  19%|█▊        | 93/500 [01:13<05:14,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  19%|█▉        | 96/500 [01:16<05:20,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  20%|█▉        | 98/500 [01:17<05:15,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  20%|█▉        | 99/500 [01:18<05:05,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  20%|██        | 101/500 [01:20<05:16,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  20%|██        | 102/500 [01:21<05:22,  1.23it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  21%|██        | 103/500 [01:21<05:17,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  21%|██        | 104/500 [01:22<05:14,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  21%|██        | 105/500 [01:23<05:00,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  21%|██▏       | 107/500 [01:24<05:05,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  22%|██▏       | 108/500 [01:25<05:06,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  22%|██▏       | 110/500 [01:27<05:00,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  22%|██▏       | 111/500 [01:27<04:58,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  22%|██▏       | 112/500 [01:28<05:01,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  23%|██▎       | 114/500 [01:30<05:16,  1.22it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  23%|██▎       | 116/500 [01:32<05:28,  1.17it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  24%|██▍       | 122/500 [01:36<05:03,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  25%|██▌       | 127/500 [01:40<04:47,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  26%|██▋       | 132/500 [01:44<05:06,  1.20it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  27%|██▋       | 133/500 [01:45<05:03,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  27%|██▋       | 134/500 [01:46<05:10,  1.18it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  27%|██▋       | 135/500 [01:47<05:10,  1.18it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  27%|██▋       | 136/500 [01:48<05:05,  1.19it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  28%|██▊       | 139/500 [01:50<04:50,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  28%|██▊       | 140/500 [01:51<04:46,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  28%|██▊       | 142/500 [01:52<04:28,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  29%|██▊       | 143/500 [01:53<04:37,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  29%|██▉       | 144/500 [01:54<04:29,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  29%|██▉       | 145/500 [01:55<04:24,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  29%|██▉       | 146/500 [01:55<04:19,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  29%|██▉       | 147/500 [01:56<04:17,  1.37it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  30%|██▉       | 148/500 [01:57<04:22,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  30%|███       | 150/500 [01:59<04:34,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  30%|███       | 152/500 [02:00<04:38,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  31%|███       | 153/500 [02:01<04:38,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  31%|███       | 154/500 [02:02<04:25,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  31%|███       | 156/500 [02:03<04:21,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  32%|███▏      | 160/500 [02:06<04:23,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  32%|███▏      | 162/500 [02:08<04:15,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  33%|███▎      | 164/500 [02:09<04:11,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  33%|███▎      | 165/500 [02:10<04:21,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  33%|███▎      | 167/500 [02:12<04:24,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  34%|███▍      | 171/500 [02:15<04:10,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  36%|███▌      | 178/500 [02:20<03:41,  1.45it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  36%|███▌      | 179/500 [02:20<03:48,  1.40it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  36%|███▌      | 180/500 [02:21<03:46,  1.41it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  37%|███▋      | 185/500 [02:25<03:57,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  38%|███▊      | 189/500 [02:28<03:49,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  39%|███▉      | 194/500 [02:32<03:55,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  40%|███▉      | 198/500 [02:35<04:05,  1.23it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  40%|███▉      | 199/500 [02:36<04:08,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  40%|████      | 200/500 [02:37<04:04,  1.23it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  41%|████      | 203/500 [02:39<03:51,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  41%|████      | 205/500 [02:41<03:43,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  42%|████▏     | 208/500 [02:43<03:47,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  42%|████▏     | 212/500 [02:46<03:31,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  43%|████▎     | 213/500 [02:47<03:36,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  43%|████▎     | 214/500 [02:47<03:37,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  43%|████▎     | 215/500 [02:48<03:49,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  43%|████▎     | 216/500 [02:49<03:52,  1.22it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  44%|████▎     | 218/500 [02:51<03:48,  1.23it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  45%|████▍     | 224/500 [02:55<03:34,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  45%|████▌     | 226/500 [02:57<03:27,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  46%|████▌     | 228/500 [02:58<03:29,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  46%|████▌     | 229/500 [02:59<03:25,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  46%|████▋     | 232/500 [03:02<03:35,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  47%|████▋     | 233/500 [03:02<03:34,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  47%|████▋     | 237/500 [03:05<03:17,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  48%|████▊     | 239/500 [03:07<03:24,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  48%|████▊     | 241/500 [03:08<03:15,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  49%|████▊     | 243/500 [03:10<03:19,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  49%|████▉     | 245/500 [03:11<03:01,  1.40it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  49%|████▉     | 247/500 [03:13<03:09,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  50%|████▉     | 248/500 [03:14<03:11,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  50%|█████     | 251/500 [03:16<03:16,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  50%|█████     | 252/500 [03:17<03:13,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  51%|█████     | 253/500 [03:18<03:14,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  51%|█████     | 254/500 [03:18<03:08,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  51%|█████▏    | 257/500 [03:20<02:46,  1.46it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  52%|█████▏    | 259/500 [03:22<02:49,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  52%|█████▏    | 261/500 [03:23<02:55,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  52%|█████▏    | 262/500 [03:24<02:47,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  53%|█████▎    | 264/500 [03:25<02:57,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  53%|█████▎    | 265/500 [03:26<03:06,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  53%|█████▎    | 266/500 [03:27<03:04,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  54%|█████▍    | 271/500 [03:31<02:51,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  55%|█████▍    | 274/500 [03:33<02:41,  1.40it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  55%|█████▌    | 276/500 [03:34<02:36,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  56%|█████▌    | 278/500 [03:36<02:44,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  57%|█████▋    | 283/500 [03:40<02:46,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  57%|█████▋    | 284/500 [03:40<02:47,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  57%|█████▋    | 287/500 [03:43<02:42,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  58%|█████▊    | 288/500 [03:43<02:42,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  58%|█████▊    | 289/500 [03:44<02:34,  1.37it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  58%|█████▊    | 290/500 [03:45<02:28,  1.41it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  58%|█████▊    | 292/500 [03:46<02:34,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  59%|█████▊    | 293/500 [03:47<02:37,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  59%|█████▉    | 295/500 [03:49<02:36,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  60%|██████    | 300/500 [03:52<02:19,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  61%|██████    | 303/500 [03:54<02:30,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  61%|██████    | 306/500 [03:57<02:29,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  61%|██████▏   | 307/500 [03:57<02:23,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  62%|██████▏   | 308/500 [03:58<02:21,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  62%|██████▏   | 310/500 [04:00<02:22,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  62%|██████▏   | 312/500 [04:01<02:26,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  63%|██████▎   | 313/500 [04:02<02:26,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  63%|██████▎   | 316/500 [04:04<02:25,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  64%|██████▎   | 318/500 [04:06<02:19,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  64%|██████▍   | 320/500 [04:08<02:21,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  64%|██████▍   | 321/500 [04:08<02:16,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  65%|██████▌   | 326/500 [04:12<02:02,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  66%|██████▌   | 328/500 [04:13<02:10,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  66%|██████▌   | 331/500 [04:16<02:10,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  67%|██████▋   | 333/500 [04:17<02:08,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  67%|██████▋   | 336/500 [04:20<02:15,  1.21it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  67%|██████▋   | 337/500 [04:21<02:12,  1.23it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  68%|██████▊   | 338/500 [04:21<02:10,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  68%|██████▊   | 339/500 [04:22<02:12,  1.22it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  68%|██████▊   | 342/500 [04:25<02:00,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  69%|██████▊   | 343/500 [04:25<01:56,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  70%|██████▉   | 348/500 [04:29<01:47,  1.41it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  70%|██████▉   | 349/500 [04:30<01:54,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  71%|███████   | 353/500 [04:33<01:58,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  71%|███████   | 354/500 [04:34<01:56,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  71%|███████   | 355/500 [04:34<01:45,  1.37it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  72%|███████▏  | 358/500 [04:36<01:43,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  72%|███████▏  | 360/500 [04:38<01:45,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  72%|███████▏  | 361/500 [04:39<01:47,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  73%|███████▎  | 363/500 [04:40<01:34,  1.44it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  73%|███████▎  | 364/500 [04:41<01:38,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  74%|███████▍  | 369/500 [04:45<01:43,  1.27it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  74%|███████▍  | 370/500 [04:45<01:43,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  74%|███████▍  | 372/500 [04:47<01:36,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  75%|███████▌  | 376/500 [04:50<01:29,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  75%|███████▌  | 377/500 [04:50<01:32,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  76%|███████▌  | 378/500 [04:51<01:30,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  76%|███████▌  | 379/500 [04:52<01:26,  1.40it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  77%|███████▋  | 385/500 [04:56<01:29,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  77%|███████▋  | 387/500 [04:58<01:25,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  78%|███████▊  | 388/500 [04:58<01:18,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  78%|███████▊  | 392/500 [05:01<01:17,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  79%|███████▊  | 393/500 [05:02<01:20,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  79%|███████▉  | 395/500 [05:04<01:24,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  79%|███████▉  | 396/500 [05:04<01:20,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  79%|███████▉  | 397/500 [05:05<01:20,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  80%|███████▉  | 398/500 [05:06<01:13,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  80%|███████▉  | 399/500 [05:07<01:15,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  80%|████████  | 400/500 [05:07<01:12,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  80%|████████  | 401/500 [05:08<01:16,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  81%|████████  | 403/500 [05:10<01:18,  1.23it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  81%|████████  | 405/500 [05:11<01:14,  1.28it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  81%|████████▏ | 407/500 [05:13<01:11,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  82%|████████▏ | 410/500 [05:15<01:03,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  83%|████████▎ | 413/500 [05:17<01:02,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  83%|████████▎ | 414/500 [05:18<01:04,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  83%|████████▎ | 416/500 [05:19<00:58,  1.45it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  83%|████████▎ | 417/500 [05:20<00:58,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  84%|████████▍ | 419/500 [05:22<01:00,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  85%|████████▍ | 424/500 [05:25<00:57,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  86%|████████▌ | 428/500 [05:28<00:51,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  86%|████████▌ | 429/500 [05:29<00:50,  1.41it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  87%|████████▋ | 434/500 [05:32<00:46,  1.41it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  87%|████████▋ | 435/500 [05:33<00:49,  1.31it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  87%|████████▋ | 437/500 [05:35<00:48,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  88%|████████▊ | 439/500 [05:36<00:46,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  88%|████████▊ | 442/500 [05:38<00:41,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  90%|████████▉ | 448/500 [05:43<00:36,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  90%|████████▉ | 449/500 [05:43<00:37,  1.37it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  90%|█████████ | 452/500 [05:45<00:33,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  92%|█████████▏| 460/500 [05:52<00:28,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  92%|█████████▏| 461/500 [05:52<00:27,  1.39it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  92%|█████████▏| 462/500 [05:53<00:25,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  93%|█████████▎| 464/500 [05:54<00:26,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  93%|█████████▎| 465/500 [05:55<00:24,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  93%|█████████▎| 467/500 [05:57<00:24,  1.34it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  94%|█████████▍| 471/500 [06:00<00:23,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  94%|█████████▍| 472/500 [06:01<00:22,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  95%|█████████▍| 473/500 [06:01<00:21,  1.26it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  95%|█████████▌| 475/500 [06:03<00:18,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  95%|█████████▌| 476/500 [06:04<00:18,  1.33it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  95%|█████████▌| 477/500 [06:04<00:17,  1.32it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  96%|█████████▌| 479/500 [06:06<00:16,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  96%|█████████▌| 480/500 [06:07<00:15,  1.29it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  96%|█████████▋| 482/500 [06:08<00:13,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  97%|█████████▋| 483/500 [06:09<00:12,  1.37it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  97%|█████████▋| 485/500 [06:10<00:11,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  97%|█████████▋| 486/500 [06:11<00:11,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  97%|█████████▋| 487/500 [06:12<00:10,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  98%|█████████▊| 488/500 [06:13<00:09,  1.25it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD:  98%|█████████▊| 490/500 [06:14<00:08,  1.24it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending AD: 100%|██████████| 500/500 [06:22<00:00,  1.31it/s]
# Appending CN:   0%|          | 1/500 [00:00<05:00,  1.66it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   1%|          | 3/500 [00:02<05:50,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   1%|▏         | 7/500 [00:05<05:52,  1.40it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   2%|▏         | 8/500 [00:05<05:56,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   2%|▏         | 10/500 [00:07<06:01,  1.36it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   2%|▏         | 11/500 [00:07<05:41,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   2%|▏         | 12/500 [00:08<05:48,  1.40it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   3%|▎         | 15/500 [00:10<05:11,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   4%|▍         | 21/500 [00:14<05:20,  1.49it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   4%|▍         | 22/500 [00:15<05:19,  1.50it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   5%|▍         | 24/500 [00:16<05:23,  1.47it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   5%|▌         | 25/500 [00:17<05:21,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   5%|▌         | 27/500 [00:18<05:20,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   6%|▌         | 31/500 [00:20<04:50,  1.61it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   7%|▋         | 33/500 [00:22<04:54,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   7%|▋         | 34/500 [00:23<05:10,  1.50it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   7%|▋         | 37/500 [00:24<04:45,  1.62it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   8%|▊         | 41/500 [00:27<05:26,  1.41it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   9%|▉         | 44/500 [00:30<05:50,  1.30it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:   9%|▉         | 46/500 [00:31<05:19,  1.42it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  10%|▉         | 48/500 [00:32<05:04,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  10%|▉         | 49/500 [00:33<05:07,  1.47it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  10%|█         | 50/500 [00:33<04:51,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  11%|█         | 53/500 [00:36<05:08,  1.45it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# ...
# Appending CN:  69%|██████▉   | 344/500 [03:47<01:41,  1.53it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  69%|██████▉   | 345/500 [03:47<01:38,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  69%|██████▉   | 347/500 [03:49<01:38,  1.56it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  70%|██████▉   | 349/500 [03:50<01:35,  1.59it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  71%|███████   | 353/500 [03:53<01:34,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  71%|███████   | 354/500 [03:53<01:41,  1.43it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  71%|███████   | 355/500 [03:54<01:45,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  71%|███████   | 356/500 [03:55<01:40,  1.44it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  71%|███████▏  | 357/500 [03:55<01:39,  1.44it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  73%|███████▎  | 364/500 [04:00<01:29,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  73%|███████▎  | 366/500 [04:01<01:32,  1.46it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  74%|███████▎  | 368/500 [04:03<01:25,  1.54it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  74%|███████▍  | 369/500 [04:03<01:26,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  74%|███████▍  | 371/500 [04:05<01:20,  1.61it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  75%|███████▍  | 373/500 [04:06<01:27,  1.45it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  75%|███████▍  | 374/500 [04:07<01:25,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  75%|███████▌  | 375/500 [04:07<01:22,  1.51it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  75%|███████▌  | 376/500 [04:08<01:18,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  75%|███████▌  | 377/500 [04:08<01:15,  1.62it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  76%|███████▌  | 378/500 [04:09<01:17,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  76%|███████▌  | 379/500 [04:10<01:14,  1.62it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  76%|███████▌  | 380/500 [04:10<01:11,  1.67it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  76%|███████▌  | 381/500 [04:11<01:16,  1.56it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  76%|███████▋  | 382/500 [04:12<01:17,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  77%|███████▋  | 383/500 [04:12<01:17,  1.50it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  77%|███████▋  | 384/500 [04:13<01:13,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  78%|███████▊  | 388/500 [04:15<01:10,  1.59it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  78%|███████▊  | 390/500 [04:17<01:10,  1.56it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  78%|███████▊  | 391/500 [04:17<01:08,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  78%|███████▊  | 392/500 [04:18<01:10,  1.54it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  79%|███████▉  | 395/500 [04:20<01:11,  1.46it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  79%|███████▉  | 397/500 [04:21<01:10,  1.45it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  80%|███████▉  | 399/500 [04:23<01:06,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  80%|████████  | 401/500 [04:24<01:03,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  81%|████████  | 404/500 [04:26<01:02,  1.53it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  81%|████████  | 406/500 [04:27<00:57,  1.64it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  82%|████████▏ | 410/500 [04:29<00:52,  1.71it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  82%|████████▏ | 411/500 [04:30<00:53,  1.67it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  83%|████████▎ | 413/500 [04:31<00:56,  1.54it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  83%|████████▎ | 414/500 [04:32<00:59,  1.45it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  83%|████████▎ | 416/500 [04:33<00:57,  1.47it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  84%|████████▍ | 419/500 [04:35<00:53,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  84%|████████▍ | 421/500 [04:37<00:51,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  84%|████████▍ | 422/500 [04:37<00:51,  1.51it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  85%|████████▍ | 424/500 [04:39<00:49,  1.53it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  85%|████████▌ | 425/500 [04:39<00:47,  1.59it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  85%|████████▌ | 427/500 [04:41<00:49,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  86%|████████▌ | 429/500 [04:42<00:45,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  87%|████████▋ | 433/500 [04:45<00:44,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  87%|████████▋ | 434/500 [04:45<00:43,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  87%|████████▋ | 435/500 [04:46<00:41,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  87%|████████▋ | 437/500 [04:47<00:42,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  88%|████████▊ | 438/500 [04:48<00:40,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  88%|████████▊ | 440/500 [04:49<00:39,  1.51it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  88%|████████▊ | 441/500 [04:50<00:37,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  88%|████████▊ | 442/500 [04:50<00:37,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  89%|████████▉ | 445/500 [04:52<00:35,  1.53it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  89%|████████▉ | 446/500 [04:53<00:34,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  89%|████████▉ | 447/500 [04:54<00:34,  1.54it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  90%|█████████ | 451/500 [04:57<00:35,  1.37it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  90%|█████████ | 452/500 [04:57<00:35,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  91%|█████████ | 454/500 [04:59<00:31,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  91%|█████████ | 455/500 [04:59<00:30,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  91%|█████████▏| 457/500 [05:01<00:28,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  92%|█████████▏| 459/500 [05:02<00:26,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  92%|█████████▏| 460/500 [05:02<00:25,  1.58it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  93%|█████████▎| 463/500 [05:04<00:22,  1.62it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  93%|█████████▎| 464/500 [05:05<00:23,  1.56it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  93%|█████████▎| 465/500 [05:06<00:22,  1.54it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  93%|█████████▎| 466/500 [05:06<00:22,  1.51it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  94%|█████████▍| 469/500 [05:08<00:19,  1.56it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  94%|█████████▍| 470/500 [05:09<00:19,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  94%|█████████▍| 471/500 [05:09<00:18,  1.57it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  94%|█████████▍| 472/500 [05:10<00:18,  1.50it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  95%|█████████▍| 473/500 [05:11<00:17,  1.52it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  95%|█████████▌| 476/500 [05:13<00:15,  1.55it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  95%|█████████▌| 477/500 [05:13<00:14,  1.60it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  96%|█████████▌| 479/500 [05:14<00:12,  1.69it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  97%|█████████▋| 483/500 [05:17<00:10,  1.68it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  97%|█████████▋| 484/500 [05:17<00:09,  1.70it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  97%|█████████▋| 487/500 [05:19<00:08,  1.62it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  98%|█████████▊| 488/500 [05:20<00:07,  1.56it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  98%|█████████▊| 489/500 [05:21<00:07,  1.53it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  98%|█████████▊| 492/500 [05:23<00:05,  1.35it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN:  99%|█████████▊| 493/500 [05:24<00:05,  1.38it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN: 100%|█████████▉| 498/500 [05:27<00:01,  1.48it/s]WARNING:gtts.lang:'en-uk' has been deprecated, falling back to 'en'. This fallback will be removed in a future version.
# Appending CN: 100%|██████████| 500/500 [05:28<00:00,  1.52it/s]
#  ✅ Dataset generation complete. 1000 new samples appended. Total samples: 2000.

# %%
import os
import pandas as pd

BASE_DIR = '/content/drive/MyDrive/synthetic_AD_dataset_final'

# Verify files were created
ad_files_count = len(os.listdir(os.path.join(BASE_DIR, 'AD/audio')))
cn_files_count = len(os.listdir(os.path.join(BASE_DIR, 'CN/audio')))
total_files = ad_files_count + cn_files_count

print(f"Files found in AD/audio: {ad_files_count}")
print(f"Files found in CN/audio: {cn_files_count}")
print(f"Total audio files found: {total_files}")

# Verify labels.csv size
labels_df = pd.read_csv(LABELS_CSV_PATH)
print(f"Rows in labels.csv: {len(labels_df)}")

if total_files > 900:
    print("\n🎉 Verification successful! You can now proceed to Cell 3 (Feature Extraction, Splitting, and Scaling).")
else:
    print("\n⚠️ WARNING: Not all files were created. Rerun the previous cell (Cell 2) and consider increasing the 'time.sleep' delay further (e.g., to 0.5 seconds) to ensure all API calls succeed.")
# Out:
# Files found in AD/audio: 1000
# Files found in CN/audio: 1000
# Total audio files found: 2000
# Rows in labels.csv: 2000
#
# 🎉 Verification successful! You can now proceed to Cell 3 (Feature Extraction, Splitting, and Scaling).

# %%
# --- STEP 7: FEATURE EXTRACTION, SPLITTING, AND SCALING ---

# Variables are inherited from previous cells: BASE_DIR, LABELS_CSV_PATH, SCALER_PATH
NUM_MFCC = 28
FEATURES_COLS = [f'mfcc_{i}' for i in range(NUM_MFCC)] + \
                [f'chroma_{i}' for i in range(12)] + \
                ['spec_centroid', 'spec_rolloff', 'zcr']
RANDOM_STATE = 42

def extract_features_from_file(file_path):
    """Extracts required acoustic features."""
    try:
        y, sr = librosa.load(file_path, duration=5, offset=0.5, sr=None)

        mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=NUM_MFCC), axis=1)
        chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr), axis=1)
        spec_centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))
        spec_rolloff = np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr))
        zcr = np.mean(librosa.feature.zero_crossing_rate(y))

        features = np.hstack([mfccs, chroma, spec_centroid, spec_rolloff, zcr])
        return pd.Series(features, index=FEATURES_COLS)

    except Exception as e:
        # If extraction fails (e.g., file corruption), return zeros
        return pd.Series(np.zeros(len(FEATURES_COLS)), index=FEATURES_COLS)

# Load labels and prepare file paths
labels_df = pd.read_csv(LABELS_CSV_PATH)

# Use vectorized string concatenation to build the filepath
labels_df['filepath'] = (
    BASE_DIR + '/' +
    labels_df['label'] + '/audio/' +
    labels_df['filename']
)

# Extract features
print("Extracting features for all samples... ")
features_df = labels_df['filepath'].apply(extract_features_from_file)
features_df['label'] = labels_df['label'].map({'CN': 0, 'AD': 1})
# Use a high threshold to remove features that are all zeros (failed files)
features_df = features_df[features_df.iloc[:, :-1].sum(axis=1) != 0]

print(f"Total features extracted: {len(features_df)}")

# --- Stratified Split (80/20) for feature data ---
X = features_df.drop('label', axis=1)
y = features_df['label']

# X_train, X_test are needed for model training in the next cell
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE, stratify=y
)

# --- Save Scaler ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
joblib.dump(scaler, SCALER_PATH)
print(f"Scaler saved to: {SCALER_PATH}")

# train_test_split COLUMN TO CSV
X_train_indices = X_train.index.tolist()
X_test_indices = X_test.index.tolist()

# Map the split back to the original labels_df indices
labels_df['train_test_split'] = labels_df.index.to_series().apply(
    lambda i: 'train' if i in X_train_indices else ('test' if i in X_test_indices else 'unknown')
)

# Save the updated DataFrame back to labels.csv
labels_df.drop('filepath', axis=1).to_csv(LABELS_CSV_PATH, index=False)

print("\n ✅ Feature extraction, scaling, and labels.csv update complete.")
# Out:
# Extracting features for all samples...
# Total features extracted: 2000
# Scaler saved to: /content/drive/MyDrive/synthetic_AD_dataset_final/scaler.pkl
#
#  ✅ Feature extraction, scaling, and labels.csv update complete.

# %%
# STEP 8: MODEL TRAINING (Final Aggressive Regularization)
print("🚀 Starting Final Model Training with Aggressive Regularization...")

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
import joblib

FINAL_MIN_SAMPLES_LEAF = 12
FINAL_MAX_DEPTH = 10
FINAL_N_ESTIMATORS = 300

best_rf_model = RandomForestClassifier(
    n_estimators=FINAL_N_ESTIMATORS,
    max_depth=FINAL_MAX_DEPTH,
    min_samples_leaf=FINAL_MIN_SAMPLES_LEAF,
    class_weight='balanced',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# Fit the model
print(f"Training model with min_samples_leaf={FINAL_MIN_SAMPLES_LEAF} and max_depth={FINAL_MAX_DEPTH}...")
best_rf_model.fit(X_train_scaled, y_train)

# Evaluation
y_pred = best_rf_model.predict(X_test_scaled)

from sklearn.metrics import roc_auc_score, confusion_matrix

# --- 1. Confusion Matrix ---
conf_matrix = confusion_matrix(y_test, y_pred)
TN, FP, FN, TP = conf_matrix.ravel()

print("\n--- Confusion Matrix (AD=1, CN=0) ---")
print("Structure: [ [True Negatives, False Positives] ]")
print("           [ [False Negatives, True Positives] ]")
print(conf_matrix)

# --- 2. Specificity ---
# Specificity = True Negatives / (True Negatives + False Positives)
specificity = TN / (TN + FP)
print(f"\n--- Specificity (True Negative Rate) ---")
print(f"Correctly Identified CN (Healthy): {specificity:.4f}")

# --- 3. AUC-ROC Score ---
try:
    y_proba_ad = best_rf_model.predict_proba(X_test_scaled)[:, 1]
    auc_score = roc_auc_score(y_test, y_proba_ad)
    print(f"\n--- AUC-ROC Score ---")
    print(f"Ability to Distinguish Classes (AUC): {auc_score:.4f}")
except Exception as e:
    print(f"Could not calculate AUC-ROC score (ensure y_proba is available): {e}")

print("\n🎯 --- Final Evaluation of Regularized Model ---")
print(f"Metrics reflect training on complex/noisy data:")
print(f"Parameters: min_samples_leaf={FINAL_MIN_SAMPLES_LEAF}, max_depth={FINAL_MAX_DEPTH}")

print(f"✅ Test Accuracy: {accuracy_score(y_test, y_pred):.4f}\n")
print("🔍 Classification Report (check AD recall):")
print(classification_report(y_test, y_pred, target_names=['CN', 'AD']))

# --- Save the Best Model ---
MODEL_PATH = "/content/drive/MyDrive/synthetic_AD_dataset_final/best_rf_model.pkl"
SCALER_PATH = "/content/drive/MyDrive/synthetic_AD_dataset_final/scaler.pkl"

joblib.dump(best_rf_model, MODEL_PATH)
# Ensure the scaler is saved again for safety
joblib.dump(scaler, SCALER_PATH)

print(f"\n💾 Final regularized model saved successfully to: {MODEL_PATH}")
# Out:
# 🚀 Starting Final Model Training with Aggressive Regularization...
# Training model with min_samples_leaf=12 and max_depth=10...
#
# --- Confusion Matrix (AD=1, CN=0) ---
# Structure: [ [True Negatives, False Positives] ]
#            [ [False Negatives, True Positives] ]
# [[196   4]
#  [  2 198]]
#
# --- Specificity (True Negative Rate) ---
# Correctly Identified CN (Healthy): 0.9800
#
# --- AUC-ROC Score ---
# Ability to Distinguish Classes (AUC): 0.9991
#
# 🎯 --- Final Evaluation of Regularized Model ---
# Metrics reflect training on complex/noisy data:
# Parameters: min_samples_leaf=12, max_depth=10
# ✅ Test Accuracy: 0.9850
#
# 🔍 Classification Report (check AD recall):
#               precision    recall  f1-score   support
#
#           CN       0.99      0.98      0.98       200
#           AD       0.98      0.99      0.99       200
#
#     accuracy                           0.98       400
#    macro avg       0.99      0.98      0.98       400
# weighted avg       0.99      0.98      0.98       400
#
#
# 💾 Final regularized model saved successfully to: /content/drive/MyDrive/synthetic_AD_dataset_final/best_rf_model.pkl

# %%
# --- STEP 9: COMPARISON MODEL TRAINING (KNN & LOGISTIC REGRESSION) ---
print("🔬 Starting Comparison Model Training (KNN & Logistic Regression)...")

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
import time
import pandas as pd
import numpy as np

comparison_models = {
    'KNN': KNeighborsClassifier(n_neighbors=5, n_jobs=-1),
    'LogReg': LogisticRegression(random_state=RANDOM_STATE, max_iter=1000, solver='liblinear')
}

comparison_results = []

# --- Training and Evaluation Loop ---
for name, model in comparison_models.items():
    print(f"\n--- Training {name} ---")
    start_time = time.time()

    # Fit the model using the scaled data (X_train_scaled, y_train inherited from Cell 5)
    model.fit(X_train_scaled, y_train)

    train_time = time.time() - start_time

    # Predict and evaluate on the test set
    y_pred_comp = model.predict(X_test_scaled)

    # Calculate key metrics
    test_accuracy = accuracy_score(y_test, y_pred_comp)

    try:
        # Get AUC-ROC score (Both KNN and LogReg support probability)
        y_proba_comp = model.predict_proba(X_test_scaled)[:, 1]
        auc_score_comp = roc_auc_score(y_test, y_proba_comp)
    except AttributeError:
        auc_score_comp = np.nan

    report = classification_report(y_test, y_pred_comp, output_dict=True, target_names=['CN', 'AD'])
    # Specificity is the recall of the negative class ('CN')
    cn_specificity = report['CN']['recall']
    ad_recall = report['AD']['recall']

    # Store results
    comparison_results.append({
        'Model': name,
        'Accuracy': f"{test_accuracy:.4f}",
        'AUC-ROC': f"{auc_score_comp:.4f}" if not np.isnan(auc_score_comp) else 'N/A',
        'Specificity (CN)': f"{cn_specificity:.4f}",
        'Recall (AD)': f"{ad_recall:.4f}",
        'Training Time (s)': f"{train_time:.2f}"
    })

# --- Final Comparison Table ---
print("\n" + "="*70)
print("📊 Comparative Model Performance (Against Random Forest)")
print("="*70)

# Add Random Forest (RF) results for direct comparison (using metrics from Cell 6 output)
rf_metrics = {
    'Model': 'Random Forest (Final)',
    'Accuracy': '0.9850',
    'AUC-ROC': '0.9991',
    'Specificity (CN)': '0.9800',
    'Recall (AD)': '0.9900',
    'Training Time (s)': '2.37'
}
comparison_results.append(rf_metrics)

comparison_df = pd.DataFrame(comparison_results)
# Sort by AUC-ROC for clear performance ranking
comparison_df = comparison_df.sort_values(by='AUC-ROC', ascending=False, ignore_index=True)

print(comparison_df.to_markdown(index=False))

print("\n✅ Comparison training complete. No models were saved to disk.")
# Out:
# 🔬 Starting Comparison Model Training (KNN & Logistic Regression)...
#
# --- Training KNN ---
#
# --- Training LogReg ---
#
# ======================================================================
# 📊 Comparative Model Performance (Against Random Forest)
# ======================================================================
# | Model                 |   Accuracy |   AUC-ROC |   Specificity (CN) |   Recall (AD) |   Training Time (s) |
# |:----------------------|-----------:|----------:|-------------------:|--------------:|--------------------:|
# | KNN                   |     0.9975 |    1      |              0.995 |          1    |                0    |
# | LogReg                |     1      |    1      |              1     |          1    |                0.02 |
# | Random Forest (Final) |     0.985  |    0.9991 |              0.98  |          0.99 |                2.37 |
#
# ✅ Comparison training complete. No models were saved to disk.

# %%
# %%writefile app.py
import streamlit as st
import joblib
import librosa
import numpy as np
import pandas as pd
import os

# --- Configuration (UPDATED FOR STREAMLIT CLOUD) ---
# The model and scaler files must be in the same GitHub directory as app.py
MODEL_PATH = 'best_rf_model.pkl'
SCALER_PATH = 'scaler.pkl'
NUM_MFCC = 28
AD_THRESHOLD = 0.40 # Threshold for high AD detection sensitivity (PAD >= 0.40)

# --- Global Assets (Model and Scaler) ---
@st.cache_resource
def load_assets():
    """Loads the model and scaler using relative paths."""
    try:
        model = joblib.load(MODEL_PATH)
        scaler = joblib.load(SCALER_PATH)
        return model, scaler
    except FileNotFoundError:
        st.error(f"Asset not found: {MODEL_PATH} or {SCALER_PATH}. Ensure they are in your GitHub repo.")
        return None, None

model, scaler = load_assets()

# --- Feature Extraction Function ---
def extract_features_streamlit(file_path):
    """Extracts acoustic features (28 MFCCs, Chroma, Spectral, ZCR)."""
    try:
        # Load audio data. You should use a lower default sample rate like 22050
        # for deployment if sr=None is causing issues, but sr=None works with pydub/ffmpeg.
        y, sr = librosa.load(file_path, duration=5, offset=0.5, sr=None)

        # Calculate features (must match the features used for training)
        mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=NUM_MFCC), axis=1)
        chroma = np.mean(librosa.feature.chroma_stft(y=y, sr=sr), axis=1)
        spec_centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))
        spec_rolloff = np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr))
        zcr = np.mean(librosa.feature.zero_crossing_rate(y))

        features = np.hstack([mfccs, chroma, spec_centroid, spec_rolloff, zcr])
        return pd.DataFrame([features])

    except Exception as e:
        st.error(f"Error extracting features: {e}")
        return None

# --- Main Streamlit App ---
st.set_page_config(page_title="🧠 AD Speech Detector", layout="centered")
st.title("🗣️ Early AD Detection from Speech")
st.markdown(f"**Screening Threshold:** AD risk flagged if probability $\\geq {AD_THRESHOLD}$.")

# Use a temporary directory for file operations that Streamlit Cloud can write to
temp_dir = "/tmp"

uploaded_file = st.file_uploader("Upload Audio File (.wav, .mp3)", type=['wav', 'mp3'])

if uploaded_file is not None and model is not None and scaler is not None:
    temp_audio_path = os.path.join(temp_dir, uploaded_file.name)
    with open(temp_audio_path, "wb") as f:
        f.write(uploaded_file.getbuffer())

    st.audio(uploaded_file, format='audio/wav')

    if st.button('Analyze Speech'):
        with st.spinner('Extracting features and predicting...'):
            feature_vector = extract_features_streamlit(temp_audio_path)

            if feature_vector is not None:
                # Scale the input features using the loaded scaler
                scaled_features = scaler.transform(feature_vector)

                # Get probability for the AD class (Class 1)
                proba = model.predict_proba(scaled_features)[0]
                ad_probability = proba[1]

                st.divider()

                # Classification based on the sensitive 0.40 threshold
                if ad_probability >= AD_THRESHOLD:
                    st.error("### ⚠️ HIGH RISK: AD-Like Speech Patterns Detected")
                    st.metric(label="Probability (AD)", value=f"{ad_probability*100:.2f}%")
                    st.info("High risk classification based on sensitivity setting.")
                else:
                    st.success("### ✅ LOW RISK: Cognitively Normal Speech")
                    st.metric(label="Probability (CN)", value=f"{proba[0]*100:.2f}%")

            # Clean up the temporary file (optional but good practice)
            if os.path.exists(temp_audio_path):
                os.remove(temp_audio_path)
# Out:
# Writing app.py

# %%
# %%writefile requirements.txt
# streamlit==1.51.0
# joblib
# librosa==0.11.0 # Use the version installed in your Colab setup
# numpy>=2.0.2
# pandas>=2.2.2
# scikit-learn>=1.6.1
# Out:
# Overwriting requirements.txt
